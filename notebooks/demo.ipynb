# %% [markdown]
# # Demo — Lab AUEC Clustering
# **Para usar este notebook: primero corre los scripts en orden.**
# ```bash
# docker compose up        # automatico
# # o manualmente:
# python scripts/01_business_understanding.py
# python scripts/02_data_understanding.py
# python scripts/03_data_preparation.py
# python scripts/04_modeling.py
# python scripts/05_evaluation.py
# ```
# Este notebook solo carga los resultados ya generados y los muestra de forma interactiva.

# %%
import sys, os
sys.path.insert(0, '..')
os.chdir('..')  # raiz del proyecto

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import pandas as pd
import pathlib

from src.utils import set_plot_style, COLORS
set_plot_style()

FIGURES = pathlib.Path("output/figures")
RESULTS = pathlib.Path("output/results")

# Verificar que los resultados existen
if not any(FIGURES.glob("*.png")):
    print("ERROR: No hay figuras en output/figures/")
    print("Ejecuta primero los scripts: docker compose up")
else:
    print(f"Figuras disponibles: {len(list(FIGURES.glob('*.png')))}")
    print(f"Resultados en: {RESULTS}")

# %% [markdown]
# ## Tabla de metricas

# %%
csv_path = RESULTS / "metricas_comparacion.csv"
if csv_path.exists():
    df = pd.read_csv(csv_path)
    display(df.style
        .highlight_max(subset=[c for c in df.columns if "↑" in c], color="#d4edda")
        .highlight_min(subset=[c for c in df.columns if "↓" in c], color="#d4edda")
        .format(precision=4))
else:
    print("No se encontro metricas_comparacion.csv — ejecuta los scripts primero")

# %% [markdown]
# ## Visualizacion del espacio latente (UMAP 2D)

# %%
img_path = FIGURES / "05_umap_2d_comparacion.png"
if img_path.exists():
    fig, ax = plt.subplots(figsize=(14, 6))
    ax.imshow(mpimg.imread(img_path))
    ax.axis("off")
    plt.tight_layout()
    plt.show()
else:
    print("Imagen no encontrada")

# %% [markdown]
# ## Matriz de confusion — AUEC K-means

# %%
img_path = FIGURES / "05_confusion_matrix_auec.png"
if img_path.exists():
    fig, ax = plt.subplots(figsize=(8, 7))
    ax.imshow(mpimg.imread(img_path))
    ax.axis("off")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Curva de aprendizaje del Autoencoder

# %%
img_path = FIGURES / "04_curva_aprendizaje_ae.png"
if img_path.exists():
    fig, ax = plt.subplots(figsize=(9, 4))
    ax.imshow(mpimg.imread(img_path))
    ax.axis("off")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Reconstruccion del Autoencoder

# %%
img_path = FIGURES / "04_reconstruccion_ae.png"
if img_path.exists():
    fig, ax = plt.subplots(figsize=(14, 3))
    ax.imshow(mpimg.imread(img_path))
    ax.axis("off")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Pureza por cluster

# %%
img_path = FIGURES / "05_pureza_por_cluster.png"
if img_path.exists():
    fig, ax = plt.subplots(figsize=(9, 4))
    ax.imshow(mpimg.imread(img_path))
    ax.axis("off")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Todas las figuras generadas

# %%
figs = sorted(FIGURES.glob("*.png"))
cols = 3
rows = (len(figs) + cols - 1) // cols
fig, axes = plt.subplots(rows, cols, figsize=(15, rows * 4))
axes = axes.flatten()
for ax, f in zip(axes, figs):
    ax.imshow(mpimg.imread(f))
    ax.set_title(f.stem, fontsize=8)
    ax.axis("off")
for ax in axes[len(figs):]:
    ax.axis("off")
plt.tight_layout()
plt.show()
